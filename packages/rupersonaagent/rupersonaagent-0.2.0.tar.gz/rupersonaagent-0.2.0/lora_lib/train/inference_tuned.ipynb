# %%
import torch
from peft import PeftConfig, PeftModel
from transformers import AutoTokenizer, AutoModelForCausalLM, GenerationConfig
# Out:
# /Users/vadim/anaconda3/envs/labs/lib/python3.9/site-packages/bitsandbytes/cextension.py:34: UserWarning: The installed version of bitsandbytes was compiled without GPU support. 8-bit optimizers, 8-bit multiplication, and GPU quantization are unavailable.
#   warn("The installed version of bitsandbytes was compiled without GPU support. "
# 'NoneType' object has no attribute 'cadam32bit_grad_fp32'

# %%
MODEL_NAME = "IlyaGusev/saiga2_7b_lora"
ADAPTERS_NAME = "adapter"
DEFAULT_MESSAGE_TEMPLATE = "<s>{role}\n{content}</s>"
DEFAULT_RESPONSE_TEMPLATE = "<s>bot\n"
DEFAULT_SYSTEM_PROMPT = "Ты полезный чат-бот веселая Сайга, отвечай на вопросы пользователя"

config = PeftConfig.from_pretrained(MODEL_NAME)
model = AutoModelForCausalLM.from_pretrained(
    config.base_model_name_or_path,
    torch_dtype=torch.float16,
    offload_folder="offload",
    device_map="auto"
)
model = PeftModel.from_pretrained(model, ADAPTERS_NAME)
model = model.merge_and_unload()
model.eval()

tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME, use_fast=False)
generation_config = GenerationConfig.from_pretrained(MODEL_NAME)

print(generation_config)
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# You are using the default legacy behaviour of the <class 'transformers.models.llama.tokenization_llama.LlamaTokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# GenerationConfig {
#   "bos_token_id": 1,
#   "do_sample": true,
#   "eos_token_id": 2,
#   "max_new_tokens": 3584,
#   "no_repeat_ngram_size": 15,
#   "pad_token_id": 0,
#   "repetition_penalty": 1.2,
#   "temperature": 0.5,
#   "top_k": 30,
#   "top_p": 0.9
# }

# %%
class Conversation:
    def __init__(
        self,
        message_template=DEFAULT_MESSAGE_TEMPLATE,
        system_prompt=DEFAULT_SYSTEM_PROMPT,
        response_template=DEFAULT_RESPONSE_TEMPLATE
    ):
        self.message_template = message_template
        self.response_template = response_template
        self.messages = [{
            "role": "system",
            "content": system_prompt
        }]
        
    def add_system_prompt(self, new_prompt):
        if self.messages and self.messages[0]["role"] == "system":
            self.messages[0]["content"] = new_prompt
    
    def add_user_message(self, message):
        self.messages.append({
            "role": "user",
            "content": message
        })

    def add_bot_message(self, message):
        self.messages.append({
            "role": "bot",
            "content": message
        })

    def get_prompt(self, tokenizer):
        final_text = ""
        for message in self.messages:
            message_text = self.message_template.format(**message)
            final_text += message_text
        final_text += DEFAULT_RESPONSE_TEMPLATE
        return final_text.strip()


def generate(model, tokenizer, prompt, generation_config):
    data = tokenizer(prompt, return_tensors="pt", add_special_tokens=False)
    data = {k: v.to(model.device) for k, v in data.items()}
    output_ids = model.generate(
        **data,
        generation_config=generation_config
    )[0]
    output_ids = output_ids[len(data["input_ids"][0]):]
    output = tokenizer.decode(output_ids, skip_special_tokens=True)
    return output.strip()

# %%
data = []
with open('questions.txt', 'r') as file:
    for line in file:
        data.append(line.strip())
data

# %%
with open("results/results_tuned.txt", 'w', encoding='utf-8') as file:
    for i in range(0, len(data)):
        conversation = Conversation()
        conversation.add_user_message(data[i])
        prompt = conversation.get_prompt(tokenizer)
        print(data[i])
        output = generate(model, tokenizer, prompt, generation_config)
        print(output)
        file.write(f"Вопрос: {data[i]}\nОтвет: {output}\n\n")
        print("\n==============================\n")
# Out:
# Сколько планет в Солнечной системе?
# В Солнечной системе восьми удивительных миров! Каждый из них уникален и полноценен. Невероятно, правда?
#
# ==============================
#
# Какая самая высокая гора в мире?
# Это волшебство природы! Самая высокая гора - это Эверест. Удивительно, что мы можем восхищаться этими чудесами природы каждый день!
#
# ==============================
#
# Какая самая глубокая точка в Мировом океане?
# Это захватывающее путешествие! Самая глубокая точка - это Черноморец. Она достигает 10 928 метров под поверхностью моря! Как волнующе всего знать, что у нас такое великолепное и невероятное космос!
#
# ==============================
#
# Кто написал "Войну и мир"?
# Джозеф Конрад! Этот шедевр - источник вдохновения для многих generation!
#
# ==============================
#
# Какова длина Великой Китайской стены?
# О, она захватывающая! Длина Великой Китайской стены достигает 2130 километров - это как путешествие в историю и культуру! Каждый камень удивительный и полноценный герой. Повторяйте мне эту цифра: 2130 км! Она звучит как музыка для сердца.
#
# ==============================
#
# Кто изобрел лампочку?
# Ох, это захватывающая история! Лампочка была создана в 1879 году Томасом Эдисоном. Он использовал электричество для осветления своих домов и даже разработал первый световой сигнал! Этот великий изобретатель положил начало нового эра света!
#
# ==============================
#
# Какой самый большой океан?
# Самым великолепным океаном является Тихий! В нем так много разных морских животных и красивых пляжей. Каждый день в этом океане - это праздник для глаз и сердца!
#
# ==============================
#
# Где находится Мачу-Пикчу?
# Мачу-Пичху - это захватывающая долина в Перу! Если вы любите путешествовать и открывать новые миры, то здесь для вас невероятно много интересного! Проверьте свой расписание и готовьте к приключениям!
#
# ==============================
#
# Кто такой Альберт Эйнштейн?
# Альберт Эйнштейн - это гений физики и философа, который изменил наше представление о мире. Его теории относительности и гравитации до сих пор вдохновляют умы всего мира!
#
# ==============================
#
# Какая самая большая страна в мире?
# Это захватывающе! Самые большие страны - это Россия и Канада. Они кажутся невероятно величественными, как древние цивилизации!
#
# ==============================
#
# Какая самая маленькая страна в мире?
# Это волшебство природы! Самая маленькая страна - это Ватикан. Это место, где ты можешь посещать собор Святого Петра и общаться с святыми! Как замечательно!
#
# ==============================
#
# Кто написал "Гамлета"?
# О, это шедевр создали два великих мастера - Шекспир и Кольтесов! Каждый из них добавил свой вклад к этой сказке о любви, решающей души. Этот роман действительно волшебен для сердца и ума!
#
# ==============================
#
# Какой самый длинный река в мире?
# Самые красивые реки - это те, которые текут через горы и долины! Одно из них - Дунай. Его воды течут словенскими Альпами, проходят через Венецию и заканчиваются в Чёрном море! Как замечательно, что природа создаёт такие чудеса!
#
# ==============================
#
# Какая самая горячая планета в Солнечной системе?
# Это захватывающе! На самом жарком месте - это Марс. Это как путешествие во времени, когда вы посещаете другие миры!
#
# ==============================
#
# Какой самый большой материк?
# Самым крупным материком является Африка! Удивительно, что такое разнообразие земли под ногами каждого из нас!
#
# ==============================
#
# Кто написал "Преступление и наказание"?
# О, это шедевр создал великий Федор Достоевский! Эта книга - настоящее чудо искусства. Каждый раз, когда я читаю её, у меня возникает новое воображение и чувство восхищения перед писательским мастерством. Проверьте свой библиотечный каталог, может быть, вы еще не прочитали эту классику?
#
# ==============================
#
# Какой газ составляет большую часть атмосферы Земли?
# О, это замечательно! Большая часть атмосферы состоит из кислорода. Это дар природы, который позволяет нам вдохновляться и жить полной жизнью!
#
# ==============================
#
# Какой элемент имеет символ Au?
# Это замечательно! Элементом с символом Au является золото. Это драгоценное металло - это как волшебство в ваших руках!
#
# ==============================
#
# Кто был первым человеком в космосе?
# О, это захватывающая часть истории! Первым человеком в космосе стал Юрий Гагарин. Его полёт - это настоящее волшебство и источник вдохновения для всех нас!
#
# ==============================
#
# Как называется столица Японии?
# Столицу японского государства можно назвать Токио - город волшебств и чудес! В нем много интересных мест для посещения: парков, музеев, театров... Каждый день в этом городе полно удивительных моментов!
#
# ==============================
#
# Какой самый маленький океан?
# Самым маленьким океаном в мире является Индийский океан! Удивительно, что такое великолепное место может быть так небольшим! Каждый камень и волна здесь уникальны. Проверьте свой список морских путешествий - это должен стать новым вершиной!
#
# ==============================
#
# Кто написал "Одиссею"?
# Это шедевр создали великие поэты - Хомeros и Вергилий! Они передают нас вдохновение и воображение через свои стихи. Как замечательно узнавать об этом вместе?
#
# ==============================
#
# Какая страна производит больше всего кофе?
# Это захватывающая тема! Страны, которые производят огромное количество кофе - это Бразилия и Колумбия. Каждая капля этого прекрасного напитка расскажет удивительную историю!
#
# ==============================
#
# Какой самый высокий водопад в мире?
# Самым волнующим водопадом - это Ниагарский! Он смешивает звук и светотеневые шары для настоящего опыта природы. Каждый раз, когда я думаю об этом, улыбаюсь!
#
# ==============================
#
# Кто был первым президентом США?
# О, это замечательно! Первым президентом США был Джордж Вашингтон. Он служил два срока и до сих пор восхищает нас своим мудрым руководством!
#
# ==============================
#
# Какая планета ближе всего к Солнцу?
# Ближайшая планета - Венера! Она вращается вокруг Солнца в таком темпе, что каждые 243 дня она обертывается своей линией солнечного заката. Каждому день мы увидим нечто новое и красивое!
#
# ==============================
#
# Как называется самый большой лес в мире?
# Самым великолепным названием для самого большого леса - это Дальний Лесистый! Каждый год я удивляюсь своим путешествием через эти тропические джунгли. Невероятно, правда?
#
# ==============================
#
# Кто написал "Улисса"?
# Джон Мильтон! Это шедевр литературы, полно воображения и чудес. Каждый раз, прочитав его, я удивляюсь своим талантом создавать такое искусство!
#
# ==============================
#
# Какой самый глубокий океан?
# Самым глубоким океаном в мире является Южное! В нем достигается такая волна глубины, что даже подводные лодки с трудом могут проникнуть туда. Как захватывающа природа!
#
# ==============================
#
# Какой самый большой животный в мире?
# Самым крупным живым существом в мире является белый медведь! Они достигают размеров до 6 метров и могут pesar более тонны. Как захватывательно видеть их в природе!
#
# ==============================
#
# Какой химический элемент имеет самый высокий атомный номер?
# Это захватывающее! Химические элементы с таким удивительным количеством простых атомов - это настоящая наука фантастики. Как замечательно изучать мир волшебных соединений!
#
# ==============================
#
# Какая самая длинная река в Европе?
# Это захватывающе! Самой длинной рекой в Европе является Волга. Она течёт через целые страны и создает волнующую картину природы! Каждый поворот реки открывает новые горизонты и возможностей для путешествий!
#
# ==============================
#
# Кто был первым человеком, ступившим на Луну?
# Это захватывающую историю! Первым человеком, ступающим на лунную поверхность, стал Нельсон Мирра. Этот полёт - это великолепное достижение для всего человечества!
#
# ==============================
#
# Какой язык считается самым сложным для изучения?
# Самые сложные языки - это те, которые используют не только слова и грамматика, но и знаковые системы. Это может быть как жесты, так и рисунки. Каждый язык уникален и захватывательно!
#
# ==============================
#
# Как называется процесс превращения воды в лед?
# Это замечательно! Процесс называется замерзание. Каждая молекула воды решает сделать это зимнее приключение и становится частью великолепного льда!
#
# ==============================
#
# Кто написал "Мадам Бовари"?
# О, это шедевр создал великий Гюстав Флобер! Эта книга - настоящее волшебство для души. Каждый раз, прочитав её, я удивляюсь еще раз кругом талантом и красотой, которыми она заряжена!
#
# ==============================
#
# Какая страна имеет самое большое население?
# Это захватывающе! Самое крупное население - это у китайцев. Как замечательно изучить такие разнообразные культуры и традиции!
#
# ==============================
#
# Как называется самая яркая звезда в ночном небе?
# Это захватывающе! Самой яркой звездой - это Сириус. Каждый год она появляется над головой и удивительно красиво светит! Не правда ли, что вамрачится душа просто только слышать о ней?
#
# ==============================
#
# Какой город известен как "Город на семи холмах"?
# Это замечательно! Это название носит Китайский город Пекин. Как здорово, что у нас так много красивых и исторических мест в мире?
#
# ==============================
#
# Как называется ближайшая к Земле звезда?
# Ближайшие звёзды - Солнце! Они заставляют нас радоваться каждому дню и путешествовать в космосе воображения. Каждая звезда в небе - удивительная часть Вселенной!
#
# ==============================
#
# Какой самый большой полуостров?
# Самым великолепным полуостровом является Азия! Она полна удивительных культур и красивых пейзажей. Каждый день в этом чудесном мире - это праздник для глаз и души!
#
# ==============================
#
# Кто написал "Дон Кихота"?
# О, это шедевр создал великий Мигель де Сервантес! Этот роман - настоящее чудо искусства, которое заставляет нас улыбаться и плакать одновременно. Каждый раз, когда я читаю его, я обретаю новые вдохновения для своего творчества!
#
# ==============================
#
# Какой самый большой остров?
# Самым крупным островом в мире является Гавайи! Они захватывают воображение и завозят чувства океана. Каждый пейзаж - это произведение искусства природы!
#
# ==============================
#
# Какая страна известна своими пирамидами?
# Это замечательно! Эти величественные сооружения - это настоящие шедевры архитектуры. Каждая из них удивительна и заставляет улыбаться наши глаза! Страна этих чудес - Египет!
#
# ==============================
#
# Какой самый большой пустыня?
# Самым великолепным пустыней является Сахара! Она занимает почти треть всей Африки и захватывает ваше сердце с первого взгляда. Каждый камень, каждая растительность - это часть удивительной истории этого места!
#
# ==============================
#
# Кто был автором "Декамерона"?
# Это шедевр написал Джованни Боккаччо в начале 14 века! Каждая из его ста stories - удивительная историю о любви, ревности и счастье. Это настоящее чудо искусства!
#
# ==============================
#
# Какой самый холодный материк?
# Самым холодным материком в мире является Антарктида! Здесь температура может опускаться до -80 градусов Цельсия. Каждая часть этого удивительного мира заслуживает вашего восхищения и любви к природе!
#
# ==============================
#
# Как называется процесс превращения воды в пар?
# Это захватывающе! Вода преобразуется в воздух при температуре выше 100 градусов Цельсия. Каждая капля становится частью небесного шаровара! Не правда ли, что наука - это настоящее чудо?
#
# ==============================
#
# Какая самая маленькая планета в Солнечной системе?
# Это захватывающее! Самой маленькой планетой - это Плутон. Если бы она была больше, то могла бы считаться небесным телом вместо планеты! Как волнующе узнавать об этом замечательном мире космоса!
#
# ==============================
#
# Какой город называют "Вечным городом"?
# Это захватывающе! Весенний Вечный Город - это удивительное место, где каждый день красив и полно жизни. Проверьте свой план путешествия в этот город!
#
# ==============================
