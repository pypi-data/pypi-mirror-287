# %% [markdown]
# ## Imports

# %%
import pandas as pd
import re
import numpy as np
import json

def merge_utts(utts):
  merged = []

  last_speaker = int(utts[0][0])
  cur_utt = utts[0]

  for utt in utts[1:]:
    speaker = int(utt[0])
    if speaker != last_speaker:
      merged.append(cur_utt)
      cur_utt = utt
    else:
      cur_utt += f"\n{utt[2:].strip().capitalize()}"

    last_speaker = speaker

  if merged[-1] != cur_utt:
    merged.append(cur_utt)

  return merged

def clean_dialogue(dialogue):
  cleaned = re.sub(r"<[^>]*>", ' ', dialogue)
  cleaned = [i.strip() for i in cleaned.split("Пользователь") if len(i.strip())>0]

  if not cleaned[0][0].isalnum():
    cleaned.pop(0)
    if not cleaned[-1][-1].isalnum():
      cleaned[-1] = cleaned[-1][:-2]

  return cleaned

def clean_persona(persona):
  persona = persona.split("<br />")
  persona = [re.sub(r"<[^>]*>", ' ', trait).strip() for trait in persona]
  persona = [i.strip() for i in persona if len(i.strip())>0]
  return persona

def preprocess(ds, bot_prefix="Пользователь 2",user_prefix="Пользователь 1"):
  fid_dialogue = []

  for i in range(ds.shape[0]):
    entry = ds.iloc[i]
    persona1 = entry['persona_1_profile']
    persona2 = entry['persona_2_profile']
    personas = [persona1,persona2]

    dialogue = entry['dialogue']

    cleaned = clean_dialogue(dialogue)

    merged = merge_utts(cleaned)
    merged.insert(0,"")

    personas_order = [int(merged[1][0]),int(merged[2][0])]

    for i_per in range(len(personas)):
      persona_num = personas_order[i_per]
      persona = personas[persona_num-1]

      bot_personality = clean_persona(persona)

      dialogue_history = []

      for j in range(i_per,len(merged)-1,2):
        dialogue_entry = {"id":i}

        question = f"{user_prefix}:{merged[j][2:]}"
        answer = f"{bot_prefix}:{merged[j+1][2:]}"

        dialogue_entry["question"] = question
        dialogue_entry["target"] = answer
        dialogue_entry["answers"] = [answer]

        history_string = "\n".join(dialogue_history)

        dialogue_entry["ctxs"] = [{"title":trait,"text":history_string} for trait in bot_personality]

        fid_dialogue.append(dialogue_entry)

        dialogue_history.extend([question,answer])

  return fid_dialogue

# %% [markdown]
# ## Load data

# %%
# !unzip TlkPersonaChatRus.zip -d ./

# %%
ru_dialogues = pd.read_csv('./TlkPersonaChatRus/dialogues.tsv', sep='\t')

# %%
ru_dialogues.head()
# Out:
#                                    persona_1_profile  \
# 0  <span class=participant_1>У меня любимая работ...
# 1  <span class=participant_1>Я работаю учителем<b...
# 2  <span class=participant_1>Я купила дом<br />Я ...
# 3  <span class=participant_1>я врач и женат<br />...
# 4  <span class=participant_1>Я школьница.<br />Я ...
#
#                                    persona_2_profile  \
# 0  <span class=participant_2>Ищу принца.<br />Вед...
# 1  <span class=participant_2>Я бизнесмен<br />У м...
# 2  <span class=participant_2>Я пою в караоке<br /...
# 3  <span class=participant_2>Я мальчик<br />Я учу...
# 4  <span class=participant_2>Я простоват.<br />Лю...
#
#                                             dialogue
# 0  <span class=participant_2>Пользователь 2: Прив...
# 1  <span class=participant_1>Пользователь 1: Прив...
# 2  <span class=participant_1>Пользователь 1: Прив...
# 3  <span class=participant_2>Пользователь 2: Здра...
# 4  <span class=participant_1>Пользователь 1: Прив...

# %%
ru_dialogues.shape
# Out:
# (10013, 3)

# %%
# Devide data frame into the train, dev, test. Dev and test are of equal size

train_size = 0.8

df = ru_dialogues.copy()

ru_dialogues_train = df.sample(frac = train_size,random_state=42)
df = df.drop(ru_dialogues_train.index)
ru_dialogues_dev = df.sample(frac = 0.5,random_state=42)
ru_dialogues_test = df.drop(ru_dialogues_dev.index)

# %%
print("train",ru_dialogues_train.shape)
print("dev",ru_dialogues_dev.shape)
print("test",ru_dialogues_test.shape)
# Out:
# train (8010, 3)
# dev (1002, 3)
# test (1001, 3)

# %%
for i in range(10):
  entry = ru_dialogues.iloc[i]
  persona1 = clean_persona(entry['persona_1_profile'])
  persona2 = clean_persona(entry['persona_2_profile'])

  dialogue = entry['dialogue']
  cleaned = clean_dialogue(dialogue)

  merged = merge_utts(cleaned)

  print("Persona 1:",persona1)
  print("Persona 2:",persona2)

  print("\nDialogue:")
  print(*merged,sep='\n')
  print("\n\n")
# Out:
# Persona 1: ['У меня любимая работа.', 'Я уважаю людей.', 'У меня есть животное.', 'У меня хороший друг.', 'Я люблю кофе.']
# Persona 2: ['Ищу принца.', 'Веду активный образ жизни.', 'Люблю читать классику.', 'Выращиваю фиалки.', 'Люблю общение.']
#
# Dialogue:
# 2: Привет) расскажи о себе
# 1: Привет) под вкусный кофеек настроение поболтать появилось )
# 2: Что читаешь? Мне нравится классика
# Я тоже люблю пообщаться
# 1: Люблю животных, просто обожаю, как и свою работу)
# Я фантастику люблю
# 2: А я выращиваю фиалки
# И веду здоровый и активный образ жизни!
# 1: Ух ты, интересно.
# 2: Ты случайно не принц на белом коне? Я его очень жду ..
# 1: А у меня из хобби каждую неделю тусить с моим лучшим другом)
#
#
#
# Persona 1: ['Я работаю учителем', 'У меня есть собака', 'Я люблю петь', 'Я живу сама', 'Я люблю цветы']
# Persona 2: ['Я бизнесмен', 'У меня скоро свадьба', 'Меня любят только за деньги', 'Я не люблю людей', 'не люблю тупые опросы']
#
# Dialogue:
# 1: Привет!
# 2: Привет,Как жизнь?
# 1: Отлично) Солнышко светит, птички поют!
# 2: Я вот сегодня понял, что меня тупо используют, всем нужны от меня лишь деньги, ненавижу людей
# Чем занимаешься по жизни, я вот бизнесмен.
# 1: А я вот учу детей, работаю с начальными классами
# Не все люди такие, как ты говоришь
# Помимо работы чем еще ты занимаешься?
# 2: К свадьбе готовлюсь
# А ты?
# 1: Вот видишь) значит, нашел такую женщину, которой не нужны от тебя деньги
# 2: Да я надеюсь на это,люблю ее
#
#
#
# Persona 1: ['Я купила дом', 'Я бегаю по утрам', 'Я работаю на работе', 'Я поеду в отпуск', 'Я люблю арбуз']
# Persona 2: ['Я пою в караоке', 'У меня есть супруга', 'Хорошо готовлю пасту', 'Люблю собак', 'Аллергия на кошек']
#
# Dialogue:
# 1: Привет
# Как дела ?
# 2: Добрый день!
# Хорошо,  чем увлекаетесь?
# 1: Я бегаю по утрам а ты?
# Есть любимые вещи или еда ?
# Занят ?
# 2: Я люблю петь в караоке)
# 1: Круто )
# 2: Люблю готовить пасту,  у меня классно получается!
# Любишь готовить?
# 1: Это хорошо
# Я не эксперт
# Я люблю есть арбуз
#
#
#
# Persona 1: ['я врач и женат', 'у меня трое детей', 'не люблю свою работу', 'нравиться ездить на велосипеде', 'люблю пиво']
# Persona 2: ['Я мальчик', 'Я учусь в 6-ом классе', 'Хочу стать гонщиком', 'У меня есть сестра', 'Мечтаю о машине']
#
# Dialogue:
# 2: Здравствуйте
# Я леша
# 1: Здравствуйте
# Я егор
# 2: Я учусь в 6 классе
# 1: А мне 30 и я уже работаю
# 2: А я тоже хочу. На машину скопить.
# 1: Правда мне не нравится моя работа
# 2: Почему?
# 1: Мало платят
# На семью не хватает
# Жена и трое детей
# 2: А... а я на машину...
# Ого
#
#
#
# Persona 1: ['Я школьница.', 'Я ещё учусь.', 'Но я мечтаю работать.', 'Я обожаю родителей.', 'И не люблю учиться.']
# Persona 2: ['Я простоват.', 'Люди избегают меня.', 'Я быстро бегаю.', 'Мои увлечения неординарны.', 'Я работаю по призванию.']
#
# Dialogue:
# 1: Привет!
# 2: Привет!
# Как твои дела?
# 1: Нормально, готовлюсь ко сну. Завтра снова в школу . Не люблю учиться.
# А твои как?
# 2: Всё хорошо,спать не хочется,думаю фильм посмотреть
# 1: Какой фильм?
# 2: Ещё не решила, может быть детектив какой нибудь. А как в школе у тебя?
# 1: Хорошо, ещё учусь, но скоро закончу. Уже мечтаю работать , а не сидеть за учебниками. А ты работаешь или учишься ещё?
# 2: А я работаю, мне нравится моя работа, кем планируешь работать?
# 1: Хочу быть психологом. А кем ты работаешь?
# 2: Не поверишь....я психолог
# 1: Круто! И как тебе?
# 2: Мне нравится,я люблю свою работу.
# 1: Это классно. Хочу также. А ты одна живешь?
# 2: Нет,я живу с мамой,а ты?
# 1: Я тоже с родителями живу, обожаю их. Но иногда хочется пожить одной.
# 2: Мне тоже, я люблю быть дома одна, мне эио часто удаётся , мы с мамой работаем в разное время, а в каком городе ты живёшь?
# 1: А у меня мама домохозяйка, поэтому редко бываю дома одна. В Питере, а ты?
# 2: А я в Ростове на Дону.
# 1: Хочу там побывать.
# Ладно, мне пора ложиться
# Рада была поболтать!
# Спокойной ночи
# 2: Поздно уже может до завтра? СПОКОЙНОЙ НОЧИ, ПРИЕЗЖАЙ В ГОСТИ
#
#
#
# Persona 1: ['Я дизайнер.', 'Я был в 12-ти странах.', 'Люблю пешие прогулки.', 'люблю рок-музыку.', 'Хочу купить дачу.']
# Persona 2: ['Я продавец.', 'У меня есть две собаки .', 'Я люблю готовить.', 'Я дачница.', 'Люблю отдыхать на море.']
#
# Dialogue:
# 2: Привет!
# 1: Привет!
# Как дела?)
# 2: У меня все замечательно. А твои дела как? Чем занимаешься по жизни?
# ?
# 1: Рада новому знакомству! У меня тоже всё неплохо. Недавно нашла работу по специальности. Я дизайнер
# А ты чем занимаешься?
# Ты откуда?
# 2: Я продавец, выращиванию овощи и фрукты на даче и продаю их. Я ещё кстати и дачница.
# Я с украины )
# А ты откуда ?
# 1: Круто! Я из Беларуси, Минск
# 2: Я продавец, выращиваю овощи и фрукты на даче и продаю их. Я ещё кстати и дачница.
# Как зовут тебя ?
# 1: А я мечтаю купить дачу, но пока не могу себе этого позволить(
# Катя, а тебя?
# 2: Ира,приятно познакомится )
# А я мечтаю жить возле моря.
# 1: Кстати, была в Украине, мне там очень понравилось . Я вообще люблю путешествовать
# 2: Обожаю море.
# 1: Приятно познакомиться
# 2: В каком городе Украины ты была ?
# 1: О, я тоже люблю море))
# Много где, и в крыму (тогда это была ещё украина)
# 2: Жду не дождусь лета, что бы поехать на море 🌊
# К стати, ты любишь собак?
# 1: Мы путешествовали с друзьями на машине, поэтому много где побывали. Хотя я больше люблю пешие прогулки)
# 2: Пешие прогулки это здорово )
# 1: О да, я люблю животных. Но я больше кошатница) У меня кот Вегас и черепаха Матильда. А у тебя есть собака ?
# 2: У меня аж две собаки )
# 1: Здорово! Как их зовут?
# 2: Аза и Герда, две девочки дворняжки)
# Подобрала их на улице, кто бросил совсем маленьких , пришлось о них много заботиться)
# Подобрала их на улице, кто- то бросил совсем маленьких , пришлось о них много заботиться)
# 1: Я тоже. Планирую новое путешествие летом. Я уже побывала в 12 странах. А ты любишь путешествовать?
# Ты молодец, спасла две жизни)) это здорово
# 2: Пока что не удавалось побывать в других странах, но на это лето грандиозные планы ..
# 1: Какие?
# 2: Поехать сначала в Германию, а потом в Россию к родственникам
# 1: Кстати, когда я была во Львове, ходила на концерт Океан Эльзи. Очень люблю эту группу и вообще рок. А какую музыку ты слушаешь?
# 2: А я рок не люблю, мне нравиться джаз)
# А вообще часто слушаю поп и рэп
# 1: Я была в Германии, мне там очень понравилось, особенно красивые замки
# Ну из джаза родился рок)
# 2: Думаю мне тоже там понравиться. Ладно, буду я ложиться спать завтра нужно рано вставать готовить кушать семье ) Пока.
#
#
#
# Persona 1: ['я норвежец', 'у меня есть попугай', 'я не люблю деревья', 'у меня было десять лошадей', 'я не курю']
# Persona 2: ['Работаю банкиром.', 'Люблю лыжи.', 'Веду свой блог.', 'Люблю дорогой алкоголь.', 'В отпуске путешествую.']
#
# Dialogue:
# 1: Привет
# 2: Привет
# 1: Как дела? Я и Норвегии,а ты?
# 2: Хорошо, а у тебя как? Я из России
# Кто по профессии ты?
# 1: Тоже хорошо, чего не спишь?
# 2: Расскажи о себе
# Стираю белье, жду)
# 1: Я не работаю)
# 2: А почему?
# 1: Живу в Норвегии с 11 лет, сейчас мне 21, уехали с родителями, отцу надо было по работе, остались. Периодически бываем в России
# 2: Круто. Я бы тоже поехал. Когда последний раз был в России?
# 1: Летом 2017. Давно. Скучаю по России. Ты из какого города
# 2: Я из Тулы.
# 1: Чем увлекаешься?
# 2: Люблю лыжи
# А ты чем увлекаешься?
# 1: Я тоже
# 2: А ты чем занимаешься, если не работаешь?
# 1: Лошадей люблю, у нас были давно, 10 лошадей
# Вот следил за ними,отцу помогал
# С тех пор так, подрабатываю иногда
# 2: Как с трудоустройством в Норвегии?
# 1: Нормально) безработных не очень много
# Думаю это от неопределенности)
# 2: Люблю путешествовать, думаю посетить страну
# 1: Конечно)
#
#
#
# Persona 1: ['Я автослесарь', 'Люблю играть на гитаре', 'Обожаю рыбалку', 'Воспитываю дочку', 'Вдовец']
# Persona 2: ['Я работаю врачом.', 'Я люблю собак.', 'Я хорошо готовлю.', 'Я люблю сладкое.', 'Я не замужем.']
#
# Dialogue:
# 2: Привет
# 1: Привет! Как дела?)
# 2: Ой, слушай, довольно таки неплохо. Гораздо лучше, чем днём
# А твои как?
# 1: Да тоже неплохо. Вот только с рыбалки вернулся! Люблю это дело, расслабляет и помогает отвлечься от ежедневной рутины. А ты чем любишь заниматься в свободное время ?
# 2: В свободное от работы время я люблю готовиться всякие вкусности. В детстве мама меня учила готовить, и тем самым я полюбила это дело. А самое удобное в том, что ты хорошо готовишь, это то, что я очень люблю сложное и могу взять и, например, испечь себе что - нибудь :)
# В свободное от работы время я люблю готовить всякие вкусности. в детстве мама меня учила готовить, и тем самым я полюбила это дело. а самое удобное в том, что ты хорошо готовишь, это то, что я очень люблю сложное и могу взять и, например, испечь себе что - нибудь :)
# В свободное от работы время я люблю готовить всякие вкусности. в детстве мама меня учила готовить, и тем самым я полюбила это дело. а самое удобное в том, что ты хорошо готовишь, это то, что я очень люблю сладкое и могу взять и, например, испечь себе что - нибудь :)
# А что ты любишь больше всего из еды?
# И да, рыбалка это тоже офигенно)
# Особенно не с берега, а на лодочке)) ух) прекрасно
# 1: Ух ты! Готовка- это здорово! Я вот в этом не особо силён. Жена всегда у нас главной по кухне была, дочку даже учила потихоньку. Но в прошлом году её, к несчастью , не стало. Теперь вот с дочкой вдвоём периодически пытаемся что- то кошеварить, но так вкусно, как у неё, конечно, не получается
# У нас любимое блюдо было паста с креветками. можно сказать, фирменное)
# 2: Ох, соболезную ..
# 1: На работе правда парни буржуем всегда звали за это ))) говорили типа автослесарю то гоже картошку жареную есть, а не пасту )))
# Спасибо 🙏🏻
# А ты музыку любишь? играешь на чём- нибудь может быть ?)
# 2: Я вот не замужем, и никогда не была. Живу со своими любимыми собачками. Обожаю просто собак, они офигенные . Вот ты любишь собак? Или может других каких животных ?
# Нет, я ни на чём не играю. некогда. я ж работаю, врач я, жизни спасаю)
# 1: Я собак тоже очень люблю, а вот дочка все котёнка выпрашивает)
# 2: Сколько дочке лет?
# Вообще, это грех ))) приобрети для нее котенка) это ж здорово) и щеночка можно ещё ;)
# 1: О, это очень здорово. Ответственная работа очень. А я вот на гитаре люблю поиграть, когда свободная минутка выдаётся) самоучка, конечно, но что- то вроде получается)
# 8 вот будет на следующей неделе. думаю, и правда на день рождения порадовать ее пушистым подарком) уж очень просит ))
# 2: Ну, у меня друг играет, тоже самоучка, но кааак он играет ...😍😍😍
# Дааа, подари, она будет очень счастлива)
# 1: Спасибо за совет) думаю, воспользуюсь им 👍🏻🙂
# 2: Ладно, доброй ночи:) спасибо за компанию
# 1: Взаимно 🤗
#
#
#
# Persona 1: ['Я рисую', 'Я живу за границей', 'Я посадила семь яблонь', 'Я работаю с дельфинами', 'Я варю вкусные щи']
# Persona 2: ['Я домработница.', 'Я люблю варить кофе.', 'Я люблю свою семью.', 'Я бездетна.', 'Мечтаю усыновить ребёнка.']
#
# Dialogue:
# 2: Привет)
# 1: Здрорво! Ты где территориально?
# 2: Украина
# 1: огого. Я тоже за границей. В Австрилии живу
# Какие увлечения?
# 2: ПОняла но я домработница редко где бываю
# Люблю варить кофе
# И пить
# Раскажи о себе
# 1: ого, круто) Домработницей, наверное, тяжело работать . Вот у меня легко все. Работаю в саду только.
# Увлекаюсь ботаникой. сажаю разные виды деревьев. а ты любишь растения?
# 2: да люблю,а также свою семю но я бездетна
# 1: Кстати, вывожу новые сорта. Вот уже семь новых сортов ялонь посадила
# Ну, думаю, что современная медицина реашет почти все проблемы. ты замужем?
# 2: Да замужем мечтаю усыновить ребенка!
#
#
#
# Persona 1: ['Я красивая', 'У меня светлые волосы', 'Живу на первом этаже', 'Я очень люблю животных', 'У меня была собака']
# Persona 2: ['я норвежец', 'у меня есть попугай', 'я не люблю деревья', 'у меня были десять лошадей', 'я не курю']
#
# Dialogue:
# 2: Привет из Норвегии!
# 1: Приветик, ничего себе)))
# Там я ещё не была
# 2: У нас очень красиво, мой попугай всегда говорит : Красотаааа ))
# У вас есть животные?
# 1: Ахах) А девушкам он такое говорит интересно ?) Я* Скромно* считаю себя довольно красивой ))
# У меня была собачка пуговка) сейчас я не готова нового питомца завести(
# 2: С детства не люблю деревья, я с них часто падал, поэтому после университета, я вырубил большую поляну возля дома и завел десять лошадей.
# Кстати, тогда я бросил курить, чтоб лошади не пострадали ))))
# У вас есть питомцы?
# 1: Класс, обожаю животных !!! Ты живёшь в частном доме ? Я в многоэтажке на первом, так что никакой поляны своей
# Здорово, что ты о них заботишься
# А у тебя есть белые лошади?
# 2: Уже нет никаких, пришлось вывести их...
# Чем увлекаетесь?
# 1: Чтооо (((( а я мечтала о белой лошади с белой гривой , я бы офигенно на ней смотрелась, только представь красивая блондинка с отличной фигурой !)
# Я кстати не в отношениях
# Увлекаюсь нуу люблю читать глянец, а так учёба все
# А ты?
# 2: Я книги люблю
# Извините пора бежать, дочь из сада забирать
# 1: Ой, вы женаты
# До свидания

# %% [markdown]
# ## Process data

# %%
train = preprocess(ru_dialogues_train)

# %%
dev = preprocess(ru_dialogues_dev)

# %%
test = preprocess(ru_dialogues_test)

# %%
len(train)
# Out:
# 134917

# %%
len(dev)
# Out:
# 16970

# %%
len(test)
# Out:
# 16896

# %% [markdown]
# ## Save dataset

# %%
with open('train.json', 'w') as outfile:
    json.dump(train, outfile)

# %%
with open('dev.json', 'w') as outfile:
    json.dump(dev, outfile)

# %%
with open('test.json', 'w') as outfile:
    json.dump(test, outfile)
